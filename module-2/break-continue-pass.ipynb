# %%
x=2
i=0

while i<x:
    print("inide x")
    i=i+1
    continue
    print("after continue")
    print(i, x)
# Out:
# inide x
# inide x

# %%
x=2
i=0

while i<x:
    print("inide x")
    i=i+1
    break
    print("after continue")
    print(i, x)
# Out:
# inide x

# %%
x=2
i=0

while i<x:
    print("inide x")
    i=i+1
    pass
    print("after continue")
    print(i, x)
# Out:
# inide x
# after continue
# 1 2
# inide x
# after continue
# 2 2
